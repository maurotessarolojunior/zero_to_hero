# %% [markdown]
# #

# %% [markdown]
# <br><br>**Lists**<br><br><br>

# %%
my_list = ['aura','campeche','trend','some money','dude']

# %%
# We can use len (), indexing and slicing

# %%
my_list
# Out:
# ['aura', 'campeche', 'trend', 'some money', 'dude']

# %%
my_list [0]
# Out:
# 'aura'

# %%
print(my_list[1])
# Out:
# campeche

# %%
my_list [2:]
# Out:
# ['trend', 'some money', 'dude']

# %%
list_A = ['30', 'twenty']

# %%
NEW = my_list + list_A

# %%
NEW
# Out:
# ['aura', 'campeche', 'trend', 'some money', 'dude', '30', 'twenty']

# %%
NEW[::-1]
# Out:
# ['twenty', '30', 'dude', 'some money', 'trend', 'campeche', 'aura']

# %%
NEW[1::-1] #makes the list go backwards but the index number don't change!
# Out:
# ['campeche', 'aura']

# %%
NEW[-2::-1]
# Out:
# ['30', 'dude', 'some money', 'trend', 'campeche', 'aura']

# %%
NEW.append('doutrina')

# %%
NEW
# Out:
# ['aura', 'campeche', 'trend', 'some money', 'dude', '30', 'twenty', 'doutrina']

# %%
NEW.sort() # This puts lists in numerical order and alphabetical

# %%
NEW
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend', 'twenty']

# %%
NEW.pop()  # Removes last item from list. As it happens locally it's not possible to attribute result to variable
# Out:
# 'twenty'

# %%
NEW
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend']

# %%
type(NEW)
# Out:
# list

# %%
type('mauro')
# Out:
# str

# %%
type(3.14)
# Out:
# float

# %%
type(3)
# Out:
# int

# %%
type(None)
# Out:
# NoneType

# %%
Sorted_list = NEW.sort()    #this DOES NOT WORK because .sort() happens localy

# %%
Sorted_list

# %%
type(Sorted_list)    #you can see Sorted_list is NoneType
# Out:
# NoneType

# %%
#If I want the above config, what I shold do is:

# %%
NEW.sort()
Sorted_list=NEW

# %%
Sorted_list
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend']

# %%
NEW
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend']

# %%
Sorted_list.reverse()
Reverse_list = Sorted_list

# %%
Reverse_list
# Out:
# ['trend', 'some money', 'dude', 'doutrina', 'campeche', 'aura', '30']

# %%
Sorted_list
# Out:
# ['trend', 'some money', 'dude', 'doutrina', 'campeche', 'aura', '30']

# %%
NEW 
#vem invertida, talvez pelas linhas acima: 
# NEW.sort()
# Sorted_list = NEW
# Sorted_list.reverse ()
# Mas ainda não faz sentido pra mim pois não houve a linha onde NEW = Reverse_list ou NEW = Sorted_list.reverse() 
# ou até Sorted_list = Sorted_list.reverse()
# A única coisa foi que o comando sorted list.reverse() aconteceu, mas como isso se aplicou novamente a NEW eu não entendi?
# Out:
# ['trend', 'some money', 'dude', 'doutrina', 'campeche', 'aura', '30']

# %%
A=NEW[::-1]  # Não acontece localmente e então posso atribuir a uma variável

# %%
NEW
# Out:
# ['trend', 'some money', 'dude', 'doutrina', 'campeche', 'aura', '30']

# %%
A
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend']

# %%
A.append([1,2,3])

# %%
print(A)
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'some money', 'trend', [1, 2, 3]]

# %%
A[6][1]
# Out:
# 'r'

# %%
len(A)
# Out:
# 8

# %%
A[7][1]
# Out:
# 2

# %%
A[5]='MONEY'

# %%
print(A)
# Out:
# ['30', 'aura', 'campeche', 'doutrina', 'dude', 'MONEY', 'trend', [1, 2, 3]]

# %% [markdown]
# <BR><BR>***Sets***<br>

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
myset.add(2) # The thing about sets is that they don't add the same item twice

# %%
myset
# Out:
# {1, 2}

# %%
mylist=['a','a','a','a','c','c','c','c','b','b','b','b','b']

# %%
set2 = set(mylist)

# %%
set2
# Out:
# {'a', 'b', 'c'}

# %%
set2.add(8)

# %%
set2
# Out:
# {8, 'a', 'b', 'c'}

# %%
type(set2)
# Out:
# set
